# %% [markdown]
# # Clustering Menggunakan K-Means
#
# Dataset diunduh ke komputer personal, dirujuk dari [KAL-Unsupervised Clustering Challenge](https://www.kaggle.com/competitions/kal-unsupervised-clustering-challange/data), sebuah kompetisi Kaggle yang diselenggarakan untuk Kelas Kecerdasan Artifisial Lanjut Teknik Informatika F 2025/2026.

# %% [markdown]
# ## import library yang diperlukan

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('../Datasets/kal_clustering.csv')
df.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_19      f_20      f_21      f_22      f_23  \
# 0     2    13  ... -0.478412 -0.757002 -0.763635 -1.090369  1.142641
# 1     2     3  ... -0.428791 -0.089908 -1.784204 -0.839474  0.459685
# 2     5    11  ... -0.413534 -1.602377  1.190984  3.267116 -0.088322
# 3     6     2  ...  0.619283  1.287801  0.532837  1.036631 -2.041828
# 4     8     7  ... -1.628830 -0.434948  0.322505  0.284326 -2.438365
#
#        f_24      f_25      f_26      f_27      f_28
# ...

# %% [markdown]
# ## **Tahap Exploratory Data Analysis**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98000 entries, 0 to 97999
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      98000 non-null  int64
#  1   f_00    98000 non-null  float64
#  2   f_01    98000 non-null  float64
#  3   f_02    98000 non-null  float64
#  4   f_03    98000 non-null  float64
#  5   f_04    98000 non-null  float64
#  6   f_05    98000 non-null  float64
#  7   f_06    98000 non-null  float64
#  8   f_07    98000 non-null  int64
#  9   f_08    98000 non-null  int64
#  10  f_09    98000 non-null  int64
#  11  f_10    98000 non-null  int64
#  12  f_11    98000 non-null  int64
#  13  f_12    98000 non-null  int64
#  14  f_13    98000 non-null  int64
#  15  f_14    98000 non-null  float64
#  16  f_15    98000 non-null  float64
#  17  f_16    98000 non-null  float64
#  18  f_17    98000 non-null  float64
#  19  f_18    98000 non-null  float64
#  20  f_19    98000 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  id          f_00          f_01          f_02          f_03  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean   48999.500000      0.001220      0.005580     -0.001042     -0.000700
# std    28290.307527      1.002801      1.000742      1.001373      1.000422
# min        0.000000     -4.732235     -4.202795     -4.377021     -4.010826
# 25%    24499.750000     -0.675226     -0.670985     -0.672779     -0.672540
# 50%    48999.500000      0.002022      0.006650     -0.000324     -0.003185
# 75%    73499.250000      0.677271      0.677746      0.677086      0.672097
# max    97999.000000      4.490521      4.324974      4.560247      4.399373
#
#                f_04          f_05          f_06          f_07          f_08  \
# count  98000.000000  98000.000000  98000.000000  98000.000000  98000.000000
# mean      -0.003522     -0.001612     -0.003042      5.545918      6.763061
# ...

# %%
X = df.drop(['id'], axis=1)

# %% [markdown]
# ### Melakukan standarisasi pada dataset

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled

pd.DataFrame(X_scaled, columns=X.columns)
# Out:
#            f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0     -0.389551 -0.917695  0.649105  0.589499 -0.824775  0.734849  2.267432
# 1     -0.688544 -0.459195  0.654321  0.995533 -1.644472  0.864967 -0.087835
# 2      0.805607  0.318753 -1.167963 -0.623531  0.108638  0.785146  1.996476
# 3     -0.500743  0.223305  0.264788  0.232124  0.417259 -1.219016  0.142257
# 4     -0.670613 -1.044343 -0.268745 -1.828801 -0.285713 -1.850223  0.786963
# ...         ...       ...       ...       ...       ...       ...       ...
# 97995  0.235712  1.650239 -0.687300  0.314279 -0.294617  0.330577  1.614571
# 97996  0.320580  0.704312  0.562897 -1.320462 -0.353107  0.183539  0.182068
# 97997 -0.249885 -0.464782  1.884586 -1.339051  0.197946 -0.557614 -0.377696
# 97998  0.309323  2.178053  0.761367  0.437241  0.467061  0.063899 -0.331837
# 97999  0.751848  0.561490  1.455817 -0.578129 -0.044815 -1.203995  0.789376
#
# ...

# %% [markdown]
# karena dataset terlalu besar (98,000 rows x 29 cols), untuk menentukan k yang cocok dengan _elbow method_, digunakan sampling dengan 10,000 data acak.

# %% [markdown]
# ### Menentukan cluster K yang cocok dengan WCSS

# %%
from sklearn.model_selection import train_test_split

X_sampled, _ = train_test_split(X_scaled, train_size=10000, random_state=42)

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X_sampled)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Elbow Method dengan sampling data')
plt.xlabel('Jumlah Cluster (k)')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Dari grafik _elbow method_ di atas, sedikit sulit untuk menentukan nilai `k` mana yang cocok, karena tidak adanya penurunan grafik yang kontras. Nilai $1 \le k < 6$ menunjukkan penurunan yang kontras, sehingga nilai `k` yang optimal dapat disimpulkan adalah $k \ge 6$. Namun, karena `k=6` telah dipilih dalam clustering sebelumnya, maka `k=9` dipilih karena menunjukkan tidak begitu landainya penurunan grafik.

# %%
k_means = KMeans(n_clusters=9, random_state=42)
cluster_labels = kmeans.fit_predict(X_scaled)
df['Predicted'] = cluster_labels

# %%
df.head()
# Out:
#    id      f_00      f_01      f_02      f_03      f_04      f_05      f_06  \
# 0   0 -0.389420 -0.912791  0.648951  0.589045 -0.830817  0.733624  2.258560
# 1   1 -0.689249 -0.453954  0.654175  0.995248 -1.653020  0.863810 -0.090651
# 2   2  0.809079  0.324568 -1.170602 -0.624491  0.105448  0.783948  1.988301
# 3   3 -0.500923  0.229049  0.264109  0.231520  0.415012 -1.221269  0.138850
# 4   4 -0.671268 -1.039533 -0.270155 -1.830264 -0.290108 -1.852809  0.781898
#
#    f_07  f_08  ...      f_20      f_21      f_22      f_23      f_24  \
# 0     2    13  ... -0.757002 -0.763635 -1.090369  1.142641 -0.884274
# 1     2     3  ... -0.089908 -1.784204 -0.839474  0.459685  1.759412
# 2     5    11  ... -1.602377  1.190984  3.267116 -0.088322 -2.168635
# 3     6     2  ...  1.287801  0.532837  1.036631 -2.041828  1.440490
# 4     8     7  ... -0.434948  0.322505  0.284326 -2.438365  1.473930
#
#        f_25      f_26      f_27      f_28  Predicted
# ...
